# %% [markdown]
# # Exploración Data Sets

# %%
import os
import numpy as np
import pandas as pd
import tqdm

# %%
[x for x in dir(os) if 'path' in x]
# Out:
# ['_fspath', 'defpath', 'fspath', 'get_exec_path', 'path', 'pathsep']

# %%
path = 'Data/'

# %% [markdown]
# # Péptidos

# %%
peptidos = pd.read_csv(f'{path}peptidos.csv', sep = ';')
peptidos.head()
# Out:
#     sequence label
# 0  LMAFYLYEV    SB
# 1  HQRLAPTMP    NB
# 2  FMNGHTHIA    SB
# 3  WLLIFHHCP    NB
# 4  MRYRVSVHP    NB

# %%
peptidos.shape
# Out:
# (15840, 2)

# %%
diccionario_pep = {}

for pep in tqdm.tqdm(peptidos['sequence']):
    
    for char in pep:
        
        if char in diccionario_pep:
            
            diccionario_pep[char] += 1
            
        else:
            diccionario_pep[char] = 1
            
diccionario_pep
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 15840/15840 [00:00<00:00, 200987.35it/s]
# {'L': 11439,
#  'M': 9644,
#  'A': 7252,
#  'F': 7808,
#  'Y': 7956,
#  'E': 6583,
#  'V': 9839,
#  'H': 6336,
#  'Q': 6335,
#  'R': 5195,
#  'P': 6621,
#  'T': 6470,
#  'N': 6313,
#  'G': 6384,
#  'I': 9071,
#  'W': 6420,
#  'C': 4362,
#  'S': 6285,
#  'K': 5562,
#  'D': 6685}

# %%
peptidos.shape
# Out:
# (15840, 2)

# %%
peptidos['sequence'].apply(lambda x: len(x)).value_counts()
# Out:
# 9    15840
# Name: sequence, dtype: int64

# %% [markdown]
# # Spotify Songs 2020

# %%
import numpy as np
import pandas as pd

import requests
from pprint import pprint
import json

from dotenv import load_dotenv
import os

import base64

from time import sleep
import pickle

load_dotenv()
# Out:
# True

# %%
CLIENT_ID = os.getenv('CLIENT_ID')
CLIENT_SECRET = os.getenv('CLIENT_SECRET')

# %%
def get_token():
    auth_string = CLIENT_ID + ':' + CLIENT_SECRET
    auth_bytes = auth_string.encode('utf-8')
    auth_base64 = str(base64.b64encode(auth_bytes), 'utf-8')

    url = 'https://accounts.spotify.com/api/token'

    headers = {
        'Authorization': 'Basic ' + auth_base64,
        'Content-Type': 'application/x-www-form-urlencoded'
    }

    data = {'grant_type': 'client_credentials'}
    result = requests.post(url, headers = headers, data = data)
    json_result = json.loads(result.content)
    token = json_result['access_token']
    return token

# %%
token = get_token()
print(token)
# Out:
# BQDO2KqeKvNh9llRM7baLE18grA5P_Jz3xN_baKAG34wvNXwI2C7BV81pH-0HXgT5ZzD6Irfl3P_jb5W_02T-3NlyX-opHzpqz7A-uRl7qHWDSEFZW4

# %%
def get_auth_header(token):
    return {'Authorization': 'Bearer ' + token}

# %%
def search(token, search):
    
    endpoint = 'https://api.spotify.com/v1/search'
    
    query = f'?q={str(search)}&type=artist&limit=1'
    
    headers = get_auth_header(token)
    
    query_url = endpoint + query
    result = requests.get(query_url, headers = headers)
    json_result = json.loads(result.content)
    
    return json_result

def search_playlist(token, search):
    
    endpoint = 'https://api.spotify.com/v1/search'
    
    query = f'?q={str(search)}&type=playlist&limit=20'
    
    headers = get_auth_header(token)
    
    query_url = endpoint + query
    result = requests.get(query_url, headers = headers)
    json_result = json.loads(result.content)
    
    return json_result

def search_playlist_v2(token, search):
    
    endpoint = 'https://api.spotify.com/v1/search'
    
    query = f'?q={str(search)}&type=playlist&limit=50'
    
    headers = get_auth_header(token)
    
    query_url = endpoint + query
    result = requests.get(query_url, headers = headers)
    json_result = json.loads(result.content)
    
    return json_result


def get_songs(token, artist_id):
    
    endpoint = f'https://api.spotify.com/v1/artists/{artist_id}/top-tracks?country=ES'
    
    headers = get_auth_header(token)

    result = requests.get(endpoint, headers = headers)
    json_result = json.loads(result.content)
    
    return json_result

# %%
def get_songs_from_playlist(token, playlist_id):
    
    endpoint = f'https://api.spotify.com/v1/playlists/{playlist_id}/tracks'
    
    headers = get_auth_header(token)

    result = requests.get(endpoint, headers = headers)
    json_result = json.loads(result.content)
    
    return json_result

# %%
songs = get_songs_from_playlist(token, '2PqDpi1qID9Zx4x9GdnjH6')

# %%
spotify.head(1)
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
#
#   track_artist  track_popularity          track_album_id  \
# 0   Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583         0.102               0.0    0.0653    0.518
#
#      tempo  duration_ms
# 0  122.036       194754
#
# [1 rows x 23 columns]

# %%
spotify['playlist_genre'].value_counts().index
# Out:
# Index(['progressive electro house', 'southern hip hop', 'indie poptimism',
#        'latin hip hop', 'neo soul', 'pop edm', 'electro house', 'hard rock',
#        'gangster rap', 'electropop', 'urban contemporary', 'hip hop',
#        'dance pop', 'classic rock', 'trap', 'tropical', 'latin pop', 'hip pop',
#        'big room', 'new jack swing', 'post-teen pop', 'permanent wave',
#        'album rock', 'reggaeton'],
#       dtype='object')

# %%
songs['items']
# Out:
# [{'added_at': '2023-10-05T00:37:44Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keeeszo'},
#    'href': 'https://api.spotify.com/v1/users/keeeszo',
#    'id': 'keeeszo',
#    'type': 'user',
#    'uri': 'spotify:user:keeeszo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#       'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#       'id': '716NhGYqD1jl2wI1Qkgq36',
#       'name': 'Bizarrap',
#       'type': 'artist',
#       'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/19HM5j0ULGSmEoRcrSe5x3'},
#       'href': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3',
#       'id': '19HM5j0ULGSmEoRcrSe5x3',
#       'name': 'Milo j',
#       'type': 'artist',
#       'uri': 'spotify:artist:19HM5j0ULGSmEoRcrSe5x3'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5NwbUP5QkkMndzwJp9kkxr'},
#     'href': 'https://api.spotify.com/v1/albums/5NwbUP5QkkMndzwJp9kkxr',
#     'id': '5NwbUP5QkkMndzwJp9kkxr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273055cea306ade28a459e948b4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02055cea306ade28a459e948b4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851055cea306ade28a459e948b4',
#       'width': 64}],
#     'name': 'Milo J: Bzrp Music Sessions, Vol. 57',
#     'release_date': '2023-10-03',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5NwbUP5QkkMndzwJp9kkxr'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#      'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#      'id': '716NhGYqD1jl2wI1Qkgq36',
#      'name': 'Bizarrap',
#      'type': 'artist',
#      'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/19HM5j0ULGSmEoRcrSe5x3'},
#      'href': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3',
#      'id': '19HM5j0ULGSmEoRcrSe5x3',
#      'name': 'Milo j',
#      'type': 'artist',
#      'uri': 'spotify:artist:19HM5j0ULGSmEoRcrSe5x3'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 189901,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'UYB282301041'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1iLbUmb2b2btyAAcQ68a1p'},
#    'href': 'https://api.spotify.com/v1/tracks/1iLbUmb2b2btyAAcQ68a1p',
#    'id': '1iLbUmb2b2btyAAcQ68a1p',
#    'is_local': False,
#    'name': 'Milo J: Bzrp Music Sessions, Vol. 57',
#    'popularity': 81,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3b3cded8570a4c91cdbcdae1629f1675ab0a1e90?cid=64f71dc4feea42ba8a001845e907b58d',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1iLbUmb2b2btyAAcQ68a1p'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-10-05T00:44:03Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keeeszo'},
#    'href': 'https://api.spotify.com/v1/users/keeeszo',
#    'id': 'keeeszo',
#    'type': 'user',
#    'uri': 'spotify:user:keeeszo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#       'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#       'id': '716NhGYqD1jl2wI1Qkgq36',
#       'name': 'Bizarrap',
#       'type': 'artist',
#       'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/19HM5j0ULGSmEoRcrSe5x3'},
#       'href': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3',
#       'id': '19HM5j0ULGSmEoRcrSe5x3',
#       'name': 'Milo j',
#       'type': 'artist',
#       'uri': 'spotify:artist:19HM5j0ULGSmEoRcrSe5x3'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4NMv3cMkDwkkR6EdLloQDB'},
#     'href': 'https://api.spotify.com/v1/albums/4NMv3cMkDwkkR6EdLloQDB',
#     'id': '4NMv3cMkDwkkR6EdLloQDB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27344fa31a89a1e549f74908a81',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0244fa31a89a1e549f74908a81',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485144fa31a89a1e549f74908a81',
#       'width': 64}],
#     'name': 'en dormir sin Madrid',
#     'release_date': '2023-10-04',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:4NMv3cMkDwkkR6EdLloQDB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#      'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#      'id': '716NhGYqD1jl2wI1Qkgq36',
#      'name': 'Bizarrap',
#      'type': 'artist',
#      'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/19HM5j0ULGSmEoRcrSe5x3'},
#      'href': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3',
#      'id': '19HM5j0ULGSmEoRcrSe5x3',
#      'name': 'Milo j',
#      'type': 'artist',
#      'uri': 'spotify:artist:19HM5j0ULGSmEoRcrSe5x3'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 137053,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'UYB282301042'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3DeZc9cOc1DM8YNoJV8lAv'},
#    'href': 'https://api.spotify.com/v1/tracks/3DeZc9cOc1DM8YNoJV8lAv',
#    'id': '3DeZc9cOc1DM8YNoJV8lAv',
#    'is_local': False,
#    'name': 'Toy en el Mic',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7fde6658bd8f5490a93c430928af87bbc4ff04d1?cid=64f71dc4feea42ba8a001845e907b58d',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:3DeZc9cOc1DM8YNoJV8lAv'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-10-05T00:44:11Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keeeszo'},
#    'href': 'https://api.spotify.com/v1/users/keeeszo',
#    'id': 'keeeszo',
#    'type': 'user',
#    'uri': 'spotify:user:keeeszo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#       'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#       'id': '716NhGYqD1jl2wI1Qkgq36',
#       'name': 'Bizarrap',
#       'type': 'artist',
#       'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/19HM5j0ULGSmEoRcrSe5x3'},
#       'href': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3',
#       'id': '19HM5j0ULGSmEoRcrSe5x3',
#       'name': 'Milo j',
#       'type': 'artist',
#       'uri': 'spotify:artist:19HM5j0ULGSmEoRcrSe5x3'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4NMv3cMkDwkkR6EdLloQDB'},
#     'href': 'https://api.spotify.com/v1/albums/4NMv3cMkDwkkR6EdLloQDB',
#     'id': '4NMv3cMkDwkkR6EdLloQDB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27344fa31a89a1e549f74908a81',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0244fa31a89a1e549f74908a81',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485144fa31a89a1e549f74908a81',
#       'width': 64}],
#     'name': 'en dormir sin Madrid',
#     'release_date': '2023-10-04',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:4NMv3cMkDwkkR6EdLloQDB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#      'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#      'id': '716NhGYqD1jl2wI1Qkgq36',
#      'name': 'Bizarrap',
#      'type': 'artist',
#      'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/19HM5j0ULGSmEoRcrSe5x3'},
#      'href': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3',
#      'id': '19HM5j0ULGSmEoRcrSe5x3',
#      'name': 'Milo j',
#      'type': 'artist',
#      'uri': 'spotify:artist:19HM5j0ULGSmEoRcrSe5x3'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 151468,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'UYB282301043'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0aPs3kmiqmt9QG7gWXdefA'},
#    'href': 'https://api.spotify.com/v1/tracks/0aPs3kmiqmt9QG7gWXdefA',
#    'id': '0aPs3kmiqmt9QG7gWXdefA',
#    'is_local': False,
#    'name': 'No soy Eterno',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6f4318a5b8c096aa2e568594b1ef5251df28a30e?cid=64f71dc4feea42ba8a001845e907b58d',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:0aPs3kmiqmt9QG7gWXdefA'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-10-05T00:44:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keeeszo'},
#    'href': 'https://api.spotify.com/v1/users/keeeszo',
#    'id': 'keeeszo',
#    'type': 'user',
#    'uri': 'spotify:user:keeeszo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#       'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#       'id': '716NhGYqD1jl2wI1Qkgq36',
#       'name': 'Bizarrap',
#       'type': 'artist',
#       'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/19HM5j0ULGSmEoRcrSe5x3'},
#       'href': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3',
#       'id': '19HM5j0ULGSmEoRcrSe5x3',
#       'name': 'Milo j',
#       'type': 'artist',
#       'uri': 'spotify:artist:19HM5j0ULGSmEoRcrSe5x3'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4NMv3cMkDwkkR6EdLloQDB'},
#     'href': 'https://api.spotify.com/v1/albums/4NMv3cMkDwkkR6EdLloQDB',
#     'id': '4NMv3cMkDwkkR6EdLloQDB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27344fa31a89a1e549f74908a81',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0244fa31a89a1e549f74908a81',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485144fa31a89a1e549f74908a81',
#       'width': 64}],
#     'name': 'en dormir sin Madrid',
#     'release_date': '2023-10-04',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:4NMv3cMkDwkkR6EdLloQDB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#      'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#      'id': '716NhGYqD1jl2wI1Qkgq36',
#      'name': 'Bizarrap',
#      'type': 'artist',
#      'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/19HM5j0ULGSmEoRcrSe5x3'},
#      'href': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3',
#      'id': '19HM5j0ULGSmEoRcrSe5x3',
#      'name': 'Milo j',
#      'type': 'artist',
#      'uri': 'spotify:artist:19HM5j0ULGSmEoRcrSe5x3'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 132294,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'UYB282301044'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4SW9gHnW8NfKOdqmh0ij45'},
#    'href': 'https://api.spotify.com/v1/tracks/4SW9gHnW8NfKOdqmh0ij45',
#    'id': '4SW9gHnW8NfKOdqmh0ij45',
#    'is_local': False,
#    'name': 'Fruto',
#    'popularity': 84,
#    'preview_url': 'https://p.scdn.co/mp3-preview/84d1b5d510f6a3f7815aa7cc3e3532d2bf5a5a25?cid=64f71dc4feea42ba8a001845e907b58d',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:4SW9gHnW8NfKOdqmh0ij45'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-10-05T00:44:19Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keeeszo'},
#    'href': 'https://api.spotify.com/v1/users/keeeszo',
#    'id': 'keeeszo',
#    'type': 'user',
#    'uri': 'spotify:user:keeeszo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#       'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#       'id': '716NhGYqD1jl2wI1Qkgq36',
#       'name': 'Bizarrap',
#       'type': 'artist',
#       'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/19HM5j0ULGSmEoRcrSe5x3'},
#       'href': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3',
#       'id': '19HM5j0ULGSmEoRcrSe5x3',
#       'name': 'Milo j',
#       'type': 'artist',
#       'uri': 'spotify:artist:19HM5j0ULGSmEoRcrSe5x3'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4NMv3cMkDwkkR6EdLloQDB'},
#     'href': 'https://api.spotify.com/v1/albums/4NMv3cMkDwkkR6EdLloQDB',
#     'id': '4NMv3cMkDwkkR6EdLloQDB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27344fa31a89a1e549f74908a81',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0244fa31a89a1e549f74908a81',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485144fa31a89a1e549f74908a81',
#       'width': 64}],
#     'name': 'en dormir sin Madrid',
#     'release_date': '2023-10-04',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:4NMv3cMkDwkkR6EdLloQDB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#      'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#      'id': '716NhGYqD1jl2wI1Qkgq36',
#      'name': 'Bizarrap',
#      'type': 'artist',
#      'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/19HM5j0ULGSmEoRcrSe5x3'},
#      'href': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3',
#      'id': '19HM5j0ULGSmEoRcrSe5x3',
#      'name': 'Milo j',
#      'type': 'artist',
#      'uri': 'spotify:artist:19HM5j0ULGSmEoRcrSe5x3'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 201272,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'UYB282301045'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4zYHsmc2V9RyR8eOA0mlx6'},
#    'href': 'https://api.spotify.com/v1/tracks/4zYHsmc2V9RyR8eOA0mlx6',
#    'id': '4zYHsmc2V9RyR8eOA0mlx6',
#    'is_local': False,
#    'name': 'Penas de Antaño',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/befdabfefcf0f3b162593d62bbb4cf4a928576aa?cid=64f71dc4feea42ba8a001845e907b58d',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:4zYHsmc2V9RyR8eOA0mlx6'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-22T04:38:06Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keeeszo'},
#    'href': 'https://api.spotify.com/v1/users/keeeszo',
#    'id': 'keeeszo',
#    'type': 'user',
#    'uri': 'spotify:user:keeeszo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#       'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#       'id': '716NhGYqD1jl2wI1Qkgq36',
#       'name': 'Bizarrap',
#       'type': 'artist',
#       'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mcTU81TzQhprhouKaTkpq'},
#       'href': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq',
#       'id': '1mcTU81TzQhprhouKaTkpq',
#       'name': 'Rauw Alejandro',
#       'type': 'artist',
#       'uri': 'spotify:artist:1mcTU81TzQhprhouKaTkpq'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6N4eyhCAqaGoT3lcEpzBmf'},
#     'href': 'https://api.spotify.com/v1/albums/6N4eyhCAqaGoT3lcEpzBmf',
#     'id': '6N4eyhCAqaGoT3lcEpzBmf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27395dcc1f2e2a2ad2050f7f41d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0295dcc1f2e2a2ad2050f7f41d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485195dcc1f2e2a2ad2050f7f41d',
#       'width': 64}],
#     'name': 'Rauw Alejandro: Bzrp Music Sessions, Vol. 56',
#     'release_date': '2023-06-21',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6N4eyhCAqaGoT3lcEpzBmf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#      'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#      'id': '716NhGYqD1jl2wI1Qkgq36',
#      'name': 'Bizarrap',
#      'type': 'artist',
#      'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mcTU81TzQhprhouKaTkpq'},
#      'href': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq',
#      'id': '1mcTU81TzQhprhouKaTkpq',
#      'name': 'Rauw Alejandro',
#      'type': 'artist',
#      'uri': 'spotify:artist:1mcTU81TzQhprhouKaTkpq'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 191254,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'UYB282301037'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2NFadq6pUeiVEihLvUlOSr'},
#    'href': 'https://api.spotify.com/v1/tracks/2NFadq6pUeiVEihLvUlOSr',
#    'id': '2NFadq6pUeiVEihLvUlOSr',
#    'is_local': False,
#    'name': 'Rauw Alejandro: Bzrp Music Sessions, Vol. 56',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f9276327f8be30a6bed15c0f1cf707fe263311b0?cid=64f71dc4feea42ba8a001845e907b58d',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2NFadq6pUeiVEihLvUlOSr'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-01T19:33:58Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keeeszo'},
#    'href': 'https://api.spotify.com/v1/users/keeeszo',
#    'id': 'keeeszo',
#    'type': 'user',
#    'uri': 'spotify:user:keeeszo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#       'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#       'id': '716NhGYqD1jl2wI1Qkgq36',
#       'name': 'Bizarrap',
#       'type': 'artist',
#       'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#       'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#       'id': '12GqGscKJx3aE4t07u7eVZ',
#       'name': 'Peso Pluma',
#       'type': 'artist',
#       'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5dKPhEYBhP8j85HcxQfaw6'},
#     'href': 'https://api.spotify.com/v1/albums/5dKPhEYBhP8j85HcxQfaw6',
#     'id': '5dKPhEYBhP8j85HcxQfaw6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27315583045b2fdb7d7bab10e81',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0215583045b2fdb7d7bab10e81',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485115583045b2fdb7d7bab10e81',
#       'width': 64}],
#     'name': 'Peso Pluma: Bzrp Music Sessions, Vol. 55',
#     'release_date': '2023-06-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5dKPhEYBhP8j85HcxQfaw6'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#      'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#      'id': '716NhGYqD1jl2wI1Qkgq36',
#      'name': 'Bizarrap',
#      'type': 'artist',
#      'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#      'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#      'id': '12GqGscKJx3aE4t07u7eVZ',
#      'name': 'Peso Pluma',
#      'type': 'artist',
#      'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
# ...
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511eff139f7452bfaa3403813d',
#       'width': 64}],
#     'name': 'Blunted Vato: Bzrp Music Sessions, Vol. 4',
#     'release_date': '2019-05-25',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:74Xg7wN9YJamrNaRZIpMhg'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#      'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#      'id': '716NhGYqD1jl2wI1Qkgq36',
#      'name': 'Bizarrap',
#      'type': 'artist',
#      'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/15RLdM61VHtknTIYIuNviR'},
#      'href': 'https://api.spotify.com/v1/artists/15RLdM61VHtknTIYIuNviR',
#      'id': '15RLdM61VHtknTIYIuNviR',
#      'name': 'Blunted Vato',
#      'type': 'artist',
#      'uri': 'spotify:artist:15RLdM61VHtknTIYIuNviR'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 109041,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'ushm21914345'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/52Ihu3LJ5du5OQUXmw7Y1G'},
#    'href': 'https://api.spotify.com/v1/tracks/52Ihu3LJ5du5OQUXmw7Y1G',
#    'id': '52Ihu3LJ5du5OQUXmw7Y1G',
#    'is_local': False,
#    'name': 'Blunted Vato: Bzrp Music Sessions, Vol. 4',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:52Ihu3LJ5du5OQUXmw7Y1G'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-05-15T21:49:57Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keeeszo'},
#    'href': 'https://api.spotify.com/v1/users/keeeszo',
#    'id': 'keeeszo',
#    'type': 'user',
#    'uri': 'spotify:user:keeeszo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#       'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#       'id': '716NhGYqD1jl2wI1Qkgq36',
#       'name': 'Bizarrap',
#       'type': 'artist',
#       'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3E7NGbzUGlOjgYY8nvtijR'},
#       'href': 'https://api.spotify.com/v1/artists/3E7NGbzUGlOjgYY8nvtijR',
#       'id': '3E7NGbzUGlOjgYY8nvtijR',
#       'name': 'Paco Amoroso',
#       'type': 'artist',
#       'uri': 'spotify:artist:3E7NGbzUGlOjgYY8nvtijR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6GEaxHZNiogI175zUr4KvH'},
#       'href': 'https://api.spotify.com/v1/artists/6GEaxHZNiogI175zUr4KvH',
#       'id': '6GEaxHZNiogI175zUr4KvH',
#       'name': 'Axel Fiks',
#       'type': 'artist',
#       'uri': 'spotify:artist:6GEaxHZNiogI175zUr4KvH'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6SjBZNyTls3sz9mRJEXlhc'},
#     'href': 'https://api.spotify.com/v1/albums/6SjBZNyTls3sz9mRJEXlhc',
#     'id': '6SjBZNyTls3sz9mRJEXlhc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273877562c64d19e12a870449eb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02877562c64d19e12a870449eb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851877562c64d19e12a870449eb',
#       'width': 64}],
#     'name': 'BZRP Music Sessions, Vol. 3 (feat. Paco Amoroso)',
#     'release_date': '2019-04-20',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6SjBZNyTls3sz9mRJEXlhc'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#      'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#      'id': '716NhGYqD1jl2wI1Qkgq36',
#      'name': 'Bizarrap',
#      'type': 'artist',
#      'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6GEaxHZNiogI175zUr4KvH'},
#      'href': 'https://api.spotify.com/v1/artists/6GEaxHZNiogI175zUr4KvH',
#      'id': '6GEaxHZNiogI175zUr4KvH',
#      'name': 'Axel Fiks',
#      'type': 'artist',
#      'uri': 'spotify:artist:6GEaxHZNiogI175zUr4KvH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3E7NGbzUGlOjgYY8nvtijR'},
#      'href': 'https://api.spotify.com/v1/artists/3E7NGbzUGlOjgYY8nvtijR',
#      'id': '3E7NGbzUGlOjgYY8nvtijR',
#      'name': 'Paco Amoroso',
#      'type': 'artist',
#      'uri': 'spotify:artist:3E7NGbzUGlOjgYY8nvtijR'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 153372,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'usdy41958946'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6GIJ1H3QklpRlRVaMG2r7j'},
#    'href': 'https://api.spotify.com/v1/tracks/6GIJ1H3QklpRlRVaMG2r7j',
#    'id': '6GIJ1H3QklpRlRVaMG2r7j',
#    'is_local': False,
#    'name': 'BZRP Music Sessions, Vol. 3 (feat. Paco Amoroso)',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6GIJ1H3QklpRlRVaMG2r7j'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-05-03T18:06:28Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keeeszo'},
#    'href': 'https://api.spotify.com/v1/users/keeeszo',
#    'id': 'keeeszo',
#    'type': 'user',
#    'uri': 'spotify:user:keeeszo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#       'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#       'id': '716NhGYqD1jl2wI1Qkgq36',
#       'name': 'Bizarrap',
#       'type': 'artist',
#       'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Jb9jVnCpWkXtoGznFJ6bF'},
#       'href': 'https://api.spotify.com/v1/artists/2Jb9jVnCpWkXtoGznFJ6bF',
#       'id': '2Jb9jVnCpWkXtoGznFJ6bF',
#       'name': 'ECKO',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Jb9jVnCpWkXtoGznFJ6bF'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/02bv0IxdjFrUAQ33JMwEEA'},
#     'href': 'https://api.spotify.com/v1/albums/02bv0IxdjFrUAQ33JMwEEA',
#     'id': '02bv0IxdjFrUAQ33JMwEEA',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f5521e9b6365e14f21b9b69b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f5521e9b6365e14f21b9b69b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f5521e9b6365e14f21b9b69b',
#       'width': 64}],
#     'name': 'Ecko: Bzrp Freestyle & Music Sessions',
#     'release_date': '2019-03-24',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:02bv0IxdjFrUAQ33JMwEEA'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#      'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#      'id': '716NhGYqD1jl2wI1Qkgq36',
#      'name': 'Bizarrap',
#      'type': 'artist',
#      'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Jb9jVnCpWkXtoGznFJ6bF'},
#      'href': 'https://api.spotify.com/v1/artists/2Jb9jVnCpWkXtoGznFJ6bF',
#      'id': '2Jb9jVnCpWkXtoGznFJ6bF',
#      'name': 'ECKO',
#      'type': 'artist',
#      'uri': 'spotify:artist:2Jb9jVnCpWkXtoGznFJ6bF'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 82641,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'usdy41912113'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4UbnMUGknRDGMgqcFXP7RK'},
#    'href': 'https://api.spotify.com/v1/tracks/4UbnMUGknRDGMgqcFXP7RK',
#    'id': '4UbnMUGknRDGMgqcFXP7RK',
#    'is_local': False,
#    'name': 'Bzrp Music Session #2',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:4UbnMUGknRDGMgqcFXP7RK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-05-03T18:04:46Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keeeszo'},
#    'href': 'https://api.spotify.com/v1/users/keeeszo',
#    'id': 'keeeszo',
#    'type': 'user',
#    'uri': 'spotify:user:keeeszo'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7fT2Me47PQ8T7954PKrcwR'},
#       'href': 'https://api.spotify.com/v1/artists/7fT2Me47PQ8T7954PKrcwR',
#       'id': '7fT2Me47PQ8T7954PKrcwR',
#       'name': 'Bhavi',
#       'type': 'artist',
#       'uri': 'spotify:artist:7fT2Me47PQ8T7954PKrcwR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5fUaIEaRhzIad7C49MqTsy'},
#       'href': 'https://api.spotify.com/v1/artists/5fUaIEaRhzIad7C49MqTsy',
#       'id': '5fUaIEaRhzIad7C49MqTsy',
#       'name': 'Halpe',
#       'type': 'artist',
#       'uri': 'spotify:artist:5fUaIEaRhzIad7C49MqTsy'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#       'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#       'id': '716NhGYqD1jl2wI1Qkgq36',
#       'name': 'Bizarrap',
#       'type': 'artist',
#       'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5RBMdy0yjeC6jlbSTv9uML'},
#     'href': 'https://api.spotify.com/v1/albums/5RBMdy0yjeC6jlbSTv9uML',
#     'id': '5RBMdy0yjeC6jlbSTv9uML',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730bfd4a044806db92bf89cd1a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020bfd4a044806db92bf89cd1a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510bfd4a044806db92bf89cd1a',
#       'width': 64}],
#     'name': 'Bhavi - BZRP Music Sessions #1',
#     'release_date': '2019-02-08',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5RBMdy0yjeC6jlbSTv9uML'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7fT2Me47PQ8T7954PKrcwR'},
#      'href': 'https://api.spotify.com/v1/artists/7fT2Me47PQ8T7954PKrcwR',
#      'id': '7fT2Me47PQ8T7954PKrcwR',
#      'name': 'Bhavi',
#      'type': 'artist',
#      'uri': 'spotify:artist:7fT2Me47PQ8T7954PKrcwR'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5fUaIEaRhzIad7C49MqTsy'},
#      'href': 'https://api.spotify.com/v1/artists/5fUaIEaRhzIad7C49MqTsy',
#      'id': '5fUaIEaRhzIad7C49MqTsy',
#      'name': 'Halpe',
#      'type': 'artist',
#      'uri': 'spotify:artist:5fUaIEaRhzIad7C49MqTsy'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#      'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#      'id': '716NhGYqD1jl2wI1Qkgq36',
#      'name': 'Bizarrap',
#      'type': 'artist',
#      'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 169718,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CA5KR1918836'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6yUFTkvNvLbDR3g0tHmQhx'},
#    'href': 'https://api.spotify.com/v1/tracks/6yUFTkvNvLbDR3g0tHmQhx',
#    'id': '6yUFTkvNvLbDR3g0tHmQhx',
#    'is_local': False,
#    'name': 'Bhavi - BZRP Music Sessions #1',
#    'popularity': 48,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f8066c7df82e8fd49869f18d7e7ddf3b7c494a1d?cid=64f71dc4feea42ba8a001845e907b58d',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6yUFTkvNvLbDR3g0tHmQhx'},
#   'video_thumbnail': {'url': None}}]

# %%
songs['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
songs['items'][0]['track']['album'].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
songs['items'][0]['track']
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#     'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#     'id': '716NhGYqD1jl2wI1Qkgq36',
#     'name': 'Bizarrap',
#     'type': 'artist',
#     'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/19HM5j0ULGSmEoRcrSe5x3'},
#     'href': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3',
#     'id': '19HM5j0ULGSmEoRcrSe5x3',
#     'name': 'Milo j',
#     'type': 'artist',
#     'uri': 'spotify:artist:19HM5j0ULGSmEoRcrSe5x3'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5NwbUP5QkkMndzwJp9kkxr'},
#   'href': 'https://api.spotify.com/v1/albums/5NwbUP5QkkMndzwJp9kkxr',
#   'id': '5NwbUP5QkkMndzwJp9kkxr',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273055cea306ade28a459e948b4',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02055cea306ade28a459e948b4',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851055cea306ade28a459e948b4',
#     'width': 64}],
#   'name': 'Milo J: Bzrp Music Sessions, Vol. 57',
#   'release_date': '2023-10-03',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5NwbUP5QkkMndzwJp9kkxr'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#    'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#    'id': '716NhGYqD1jl2wI1Qkgq36',
#    'name': 'Bizarrap',
#    'type': 'artist',
#    'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/19HM5j0ULGSmEoRcrSe5x3'},
#    'href': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3',
#    'id': '19HM5j0ULGSmEoRcrSe5x3',
#    'name': 'Milo j',
#    'type': 'artist',
#    'uri': 'spotify:artist:19HM5j0ULGSmEoRcrSe5x3'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 189901,
#  'episode': False,
#  'explicit': False,
#  'external_ids': {'isrc': 'UYB282301041'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/1iLbUmb2b2btyAAcQ68a1p'},
#  'href': 'https://api.spotify.com/v1/tracks/1iLbUmb2b2btyAAcQ68a1p',
#  'id': '1iLbUmb2b2btyAAcQ68a1p',
#  'is_local': False,
#  'name': 'Milo J: Bzrp Music Sessions, Vol. 57',
#  'popularity': 81,
#  'preview_url': 'https://p.scdn.co/mp3-preview/3b3cded8570a4c91cdbcdae1629f1675ab0a1e90?cid=64f71dc4feea42ba8a001845e907b58d',
#  'track': True,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:1iLbUmb2b2btyAAcQ68a1p'}

# %%
[x['name'] for x in songs['items'][0]['track']['artists']]
# Out:
# ['Bizarrap', 'Milo j']

# %%
results = []

for song in songs['items']:
    
    #track data
    track = song['track']
    track_id = track['id']
    track_name = track['name']
    track_artists = [artist['name'] for artist in track['artists']]
    track_popularity = track['popularity']
    
    #album data
    album = song['track']['album']
    track_album_id = album['id']
    track_album_name = album['name']
    track_album_release_date = album['release_date']
    
    #playlist data
    playlist = song[]
    
    print(track_album_release_date)
    
    break
# Out:
# 2023-10-03

# %%
canciones = get_songs(token, artist_id)

# %%
artista = search(token, 'Bizarrap')

# %%
playlist = search_playlist(token, 'Bizarrap')

# %%
playlist['playlists']['items'][0].keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
playlist['playlists']['items'][0]
# Out:
# {'collaborative': False,
#  'description': 'Playlist de todas las sesiones de Bizarrap enlistadas por fecha, actualizadas a Octubre del 2023.   Bizarrap Sessions - Bizarrap Music Sessions',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/2PqDpi1qID9Zx4x9GdnjH6'},
#  'href': 'https://api.spotify.com/v1/playlists/2PqDpi1qID9Zx4x9GdnjH6',
#  'id': '2PqDpi1qID9Zx4x9GdnjH6',
#  'images': [{'height': None,
#    'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb3889497605e0953fecaeac53',
#    'width': None}],
#  'name': 'BZRP MUSIC SESSIONS',
#  'owner': {'display_name': 'Romeo Aquino',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/keeeszo'},
#   'href': 'https://api.spotify.com/v1/users/keeeszo',
#   'id': 'keeeszo',
#   'type': 'user',
#   'uri': 'spotify:user:keeeszo'},
#  'primary_color': None,
#  'public': None,
#  'snapshot_id': 'Mjc0LDgxZTU0M2JkMGU5ZTc2NzhjNGJmNTY4N2EzNGYwYTM3NDQ1YWJkOWE=',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/2PqDpi1qID9Zx4x9GdnjH6/tracks',
#   'total': 61},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:2PqDpi1qID9Zx4x9GdnjH6'}

# %%
token = get_token()

genres = ['edm', 'rap', 'pop', 'r&b', 'latin', 'rock']

results = []

none_counter = 0

for genre in genres:
    
    playlists = search_playlist_v2(token, genre)
    playlists = playlists['playlists']['items']
    
    songs_counter = 0
    
    for playlist in tqdm.tqdm(playlists):
        
        #playlist data
        playlist_id = playlist['id']
        playlist_name = playlist['name']
        playlist_genre = genre
        
        songs = get_songs_from_playlist(token, playlist_id)
        songs = songs['items']
        
        for idx, song in enumerate(songs):
        
            try: 
                #track data
                track = song['track']
                
                """if track == None:
                    none_counter += 1
                    print(none_counter)"""

                if track is not None or track != None :

                    track_id = track['id']
                    track_name = track['name']
                    track_artists = [artist['name'] for artist in track['artists']]
                    track_popularity = track['popularity']

                    #album data
                    album = track['album']
                    track_album_id = album['id']
                    track_album_name = album['name']
                    track_album_release_date = album['release_date']

                    results.append([track_id, track_name, track_artists, track_popularity,track_album_id, track_album_name, track_album_release_date,playlist_name, playlist_id, playlist_genre])
            
            except:
                print(f'Ha fallado la cancion #{idx} dela playlist {playlist_name} - {playlist_id}')
            
        songs_counter += len(songs)    
            
        sleep(0.5) #Este sleep es para bajar el ritmo de llamadas a la API para sacar las canciones de cada playlist encontrado
        
    print(f'La API ha buscado datos de {genre}, ha sacado {len(playlists)} playlists y {songs_counter} canciones')    
        
    sleep(1.5) #Este sleep es para bajar el ritmo de llamadas a la API para sacar los playlists de cada genero
    
df = pd.DataFrame(results, columns = ['track_id', 'track_name', 'track_artist', 'track_popularity', 'track_album_id', 'track_album_name', 'track_album_release_date', 'playlist_name', 'playlist_id', 'playlist_genre'])
df.to_csv('Data/spotifyAPI_v2.csv', index = False)
df.to_pickle('Data/spotifyAPI_v2.pkl')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:53<00:00,  1.06s/it]
# La API ha buscado datos de edm, ha sacado 50 playlists y 3177 canciones
# 100%|██████████████████████████████████████████████████████████████████████████████████| 49/49 [00:52<00:00,  1.06s/it]
# La API ha buscado datos de rap, ha sacado 49 playlists y 3714 canciones
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:51<00:00,  1.04s/it]
# La API ha buscado datos de pop, ha sacado 50 playlists y 3881 canciones
# 100%|██████████████████████████████████████████████████████████████████████████████████| 43/43 [00:46<00:00,  1.09s/it]
# La API ha buscado datos de r&b, ha sacado 43 playlists y 2770 canciones
# 100%|██████████████████████████████████████████████████████████████████████████████████| 49/49 [00:53<00:00,  1.10s/it]
# La API ha buscado datos de latin, ha sacado 49 playlists y 3708 canciones
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:54<00:00,  1.09s/it]
# La API ha buscado datos de rock, ha sacado 50 playlists y 4141 canciones

# %%
search_playlist_v2(token, 'edm')
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=edm&type=playlist&offset=0&limit=50',
#   'items': [{'collaborative': False,
#     'description': 'EDM House music picked just for you',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EIdDyy28MYSyS'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIdDyy28MYSyS',
#     'id': '37i9dQZF1EIdDyy28MYSyS',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/desc/EDM%20House/en/large',
#       'width': None}],
#     'name': 'EDM House Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTk3MjAsMDAwMDAwMDBlZmMyYWY0YTg0OTE5MTA5ZDhmNzE4ZDA1MzUxZjczNQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIdDyy28MYSyS/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EIdDyy28MYSyS'},
#    {'collaborative': False,
#     'description': 'Electronic Dance Music Playlist with the best new hits from 2021 and a few throwbacks from 2000s - 2020.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2e3dcRuo9uDH6qD3NOGKAL'},
#     'href': 'https://api.spotify.com/v1/playlists/2e3dcRuo9uDH6qD3NOGKAL',
#     'id': '2e3dcRuo9uDH6qD3NOGKAL',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb641437f763d7baec091e7ca7',
#       'width': None}],
#     'name': 'EDM Music 2023 (Top 100)',
#     'owner': {'display_name': 'Unplugged',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/312avoycbyo353bvbqm2mpdnghjy'},
#      'href': 'https://api.spotify.com/v1/users/312avoycbyo353bvbqm2mpdnghjy',
#      'id': '312avoycbyo353bvbqm2mpdnghjy',
#      'type': 'user',
#      'uri': 'spotify:user:312avoycbyo353bvbqm2mpdnghjy'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzM5NywzOTZmYTgzZWMzNGY0MjA1OWQ4ZGMwOGFjYTU5MmI4MjllNjA4M2Qw',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2e3dcRuo9uDH6qD3NOGKAL/tracks',
#      'total': 138},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2e3dcRuo9uDH6qD3NOGKAL'},
#    {'collaborative': False,
#     'description': 'Die besten EDM-Hits für euer Weihnachtsfest &#x2F; The best EDM hits for Christmas!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0GKv1UM2QjEkUNeVbUsPUI'},
#     'href': 'https://api.spotify.com/v1/playlists/0GKv1UM2QjEkUNeVbUsPUI',
#     'id': '0GKv1UM2QjEkUNeVbUsPUI',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebba2917917e8b54934748fe6d3',
#       'width': None}],
#     'name': 'EDM Christmas Songs',
#     'owner': {'display_name': 'DJ Mag Germany',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/yehf0hnhtmtvugt4khrtq3a3t'},
#      'href': 'https://api.spotify.com/v1/users/yehf0hnhtmtvugt4khrtq3a3t',
#      'id': 'yehf0hnhtmtvugt4khrtq3a3t',
#      'type': 'user',
#      'uri': 'spotify:user:yehf0hnhtmtvugt4khrtq3a3t'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'Mzk0LDFjNDgzOTRmMjdhMmYyMjI4MWE5MDI5Y2NlZTE1NTA3NzA2NWQxZGI=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0GKv1UM2QjEkUNeVbUsPUI/tracks',
#      'total': 164},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0GKv1UM2QjEkUNeVbUsPUI'},
#    {'collaborative': False,
#     'description': 'The greatest EDM bangers in one playlist, from 2000s-2023!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0ftBbYPc1Oyz7WGokBtBr3'},
#     'href': 'https://api.spotify.com/v1/playlists/0ftBbYPc1Oyz7WGokBtBr3',
#     'id': '0ftBbYPc1Oyz7WGokBtBr3',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb12aba3bf3a2f43787ac92f8f',
#       'width': None}],
#     'name': 'EDM BANGERS ❤️\u200d🔥🤯🌎',
#     'owner': {'display_name': 'Neila San',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/jasipl5pbb3cgda8akcyce38m'},
#      'href': 'https://api.spotify.com/v1/users/jasipl5pbb3cgda8akcyce38m',
#      'id': 'jasipl5pbb3cgda8akcyce38m',
#      'type': 'user',
#      'uri': 'spotify:user:jasipl5pbb3cgda8akcyce38m'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY1Myw5NDZkMDAzMmU5NjZiMjBlMjUxZTFlMzcxNDMwYWNhMTJjYThmM2U1',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0ftBbYPc1Oyz7WGokBtBr3/tracks',
#      'total': 186},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0ftBbYPc1Oyz7WGokBtBr3'},
#    {'collaborative': False,
#     'description': 'Hype EDM music picked just for you',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EIhSskk1NQ9dI'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIhSskk1NQ9dI',
#     'id': '37i9dQZF1EIhSskk1NQ9dI',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/desc/Hype%20EDM/en/large',
#       'width': None}],
#     'name': 'Hype EDM Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTk3MjAsMDAwMDAwMDBmNTE4YmMxMWMwZWE0NTJlMTFlODlmMGQyYTY1NWQ5Yw==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIhSskk1NQ9dI/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EIhSskk1NQ9dI'},
#    {'collaborative': False,
#     'description': 'Home is where the main stage is. 💗',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1kCIzMYtzum'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1kCIzMYtzum',
#     'id': '37i9dQZF1DX1kCIzMYtzum',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003d726493b531d4e8f6910a969',
#       'width': None}],
#     'name': 'EDM 2024',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTcwMzgyNjAwMCwwMDAwMDAwMDY0ZDIwZmFhMjFmYjU0NGFiYjQxZWQxNTE5OGY2ZmFm',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1kCIzMYtzum/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX1kCIzMYtzum'},
#    {'collaborative': False,
#     'description': 'EDM Hard Bass music picked just for you',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EIcXb2cv4lc0r'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIcXb2cv4lc0r',
#     'id': '37i9dQZF1EIcXb2cv4lc0r',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/desc/EDM%20Hard%20Bass/en/large',
#       'width': None}],
#     'name': 'EDM Hard Bass Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTk3MjAsMDAwMDAwMDBjZjJlOTU0M2JlMjE5ZGZjZmJjN2NhZDU3NWQ0Y2ZlMQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIcXb2cv4lc0r/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EIcXb2cv4lc0r'},
#    {'collaborative': False,
#     'description': 'Classic EDM Hits.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/1lS6v9h4MXOw6f6y8MkS8w'},
#     'href': 'https://api.spotify.com/v1/playlists/1lS6v9h4MXOw6f6y8MkS8w',
#     'id': '1lS6v9h4MXOw6f6y8MkS8w',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb87c902ab559476f00ebd8072',
#       'width': None}],
#     'name': 'EDM Classics (Top 100)',
#     'owner': {'display_name': 'Den Haku Records',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/ywuydivm5d8upiut8z0ylm4sh'},
#      'href': 'https://api.spotify.com/v1/users/ywuydivm5d8upiut8z0ylm4sh',
#      'id': 'ywuydivm5d8upiut8z0ylm4sh',
#      'type': 'user',
#      'uri': 'spotify:user:ywuydivm5d8upiut8z0ylm4sh'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU5LGUxZDQ3ZDkxMDg3MDI1YzYzNGM0MTc1NDQxMjgwYjYzNTZhYzViNTg=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/1lS6v9h4MXOw6f6y8MkS8w/tracks',
#      'total': 74},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1lS6v9h4MXOw6f6y8MkS8w'},
#    {'collaborative': False,
#     'description': 'Workout EDM music picked just for you',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EIdEHUkBXtKK5'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIdEHUkBXtKK5',
#     'id': '37i9dQZF1EIdEHUkBXtKK5',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/desc/Workout%20EDM/en/large',
#       'width': None}],
#     'name': 'Workout EDM Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTk3MjAsMDAwMDAwMDAzMDcwMjJiMTE5MjBhOGI2ODNlMzljY2E1OTdlYzQzNA==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIdEHUkBXtKK5/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EIdEHUkBXtKK5'},
#    {'collaborative': False,
#     'description': '100% clássicos.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX3Kdv0IChEm9'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3Kdv0IChEm9',
#     'id': '37i9dQZF1DX3Kdv0IChEm9',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000032aecfef2647621adf8a3d4ae',
#       'width': None}],
#     'name': 'EDM Hits',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY4NjkxOTU3MywwMDAwMDAwMDMxMTQ2YzI1YTNiODc4OWQ5ZTIzNWUyMjI4ZWEyYWYy',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3Kdv0IChEm9/tracks',
#      'total': 60},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX3Kdv0IChEm9'},
#    {'collaborative': False,
#     'description': 'Club EDM music picked just for you',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EIdUl76XD3qNH'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIdUl76XD3qNH',
#     'id': '37i9dQZF1EIdUl76XD3qNH',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/desc/Club%20EDM/en/large',
#       'width': None}],
#     'name': 'Club EDM Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTk3MjAsMDAwMDAwMDA1ZTg3ZWU1N2M1OTEzNGMzZDgzNDZmOGM2Njc2MzJjOQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIdUl76XD3qNH/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EIdUl76XD3qNH'},
#    {'collaborative': False,
#     'description': 'Best EDM Remixes Hits of 2023, 2022, 2021, 2020, 2019 and before!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/7J0ssQcMWpjaR5R59eESWP'},
#     'href': 'https://api.spotify.com/v1/playlists/7J0ssQcMWpjaR5R59eESWP',
#     'id': '7J0ssQcMWpjaR5R59eESWP',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebba95eddcbc0bd7f51aa8967a2',
#       'width': None}],
#     'name': 'EDM Remixes of Popular Songs',
#     'owner': {'display_name': 'DailyMixFR',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/dailymixfr'},
#      'href': 'https://api.spotify.com/v1/users/dailymixfr',
#      'id': 'dailymixfr',
#      'type': 'user',
#      'uri': 'spotify:user:dailymixfr'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzM2NixjZmQ2YTBhMjM5MmU5ODA4MzAzMjM0YjM0NjJjNWY4ZDU2YmQxMTZi',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/7J0ssQcMWpjaR5R59eESWP/tracks',
#      'total': 69},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:7J0ssQcMWpjaR5R59eESWP'},
#    {'collaborative': False,
#     'description': 'TECHNO FIESTAS 2024 - EDM PARTY 2024 - EDM Hits 2024 - EDM Playlist 2024 - Tomorrowland 2024 - Party Songs 2024 - Eletronicas 2024',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0QXFfy6gn85CnyYDYcND4z'},
#     'href': 'https://api.spotify.com/v1/playlists/0QXFfy6gn85CnyYDYcND4z',
#     'id': '0QXFfy6gn85CnyYDYcND4z',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbaf92d9e6d092cec5a36e1136',
#       'width': None}],
#     'name': 'EDM BANGERS 🔥🎧',
#     'owner': {'display_name': 'Groove Bassment',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/groovebassment'},
#      'href': 'https://api.spotify.com/v1/users/groovebassment',
#      'id': 'groovebassment',
#      'type': 'user',
#      'uri': 'spotify:user:groovebassment'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTA0OSw4MTVhY2ZmYzZhYzk3MzhmNjczMGZmYWYzNDJiNzhiMWNiYmVjYTA4',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0QXFfy6gn85CnyYDYcND4z/tracks',
#      'total': 233},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0QXFfy6gn85CnyYDYcND4z'},
#    {'collaborative': False,
#     'description': 'Hard hitting EDM and Bass Music hits mix for Gym or Street Motivation!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0TsHgCCpifeNJg3d8z3Nfv'},
#     'href': 'https://api.spotify.com/v1/playlists/0TsHgCCpifeNJg3d8z3Nfv',
#     'id': '0TsHgCCpifeNJg3d8z3Nfv',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb3ca7f321c974f55a4d320f14',
#       'width': None}],
#     'name': 'EDM Workout 2023 | Training Hits',
#     'owner': {'display_name': 'Naeleck',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/11124443444'},
#      'href': 'https://api.spotify.com/v1/users/11124443444',
#      'id': '11124443444',
#      'type': 'user',
#      'uri': 'spotify:user:11124443444'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTgwNyxmOWE1ZDQ5MDliNDcyZjdjNmM5ZjJkY2NkMmM3MjE1NDRlNWYzMDAx',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0TsHgCCpifeNJg3d8z3Nfv/tracks',
#      'total': 115},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0TsHgCCpifeNJg3d8z3Nfv'},
#    {'collaborative': False,
#     'description': 'EDM Pop music picked just for you',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EIcQWumeWY91g'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIcQWumeWY91g',
#     'id': '37i9dQZF1EIcQWumeWY91g',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/desc/EDM%20Pop/en/large',
#       'width': None}],
#     'name': 'EDM Pop Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTk3MjAsMDAwMDAwMDA5OTM4ZjY0NGExMjRlZDM0ODYyYWZkMTNjZjEwNTY4NA==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIcQWumeWY91g/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EIcQWumeWY91g'},
#    {'collaborative': False,
#     'description': 'Create the new vibe by mixing in the retro sounds.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXafD1g5rer7q'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXafD1g5rer7q',
#     'id': '37i9dQZF1DXafD1g5rer7q',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003bc42ba887b3369b48d4265af',
#       'width': None}],
#     'name': 'EDM Samplings',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTcwMjI1OTUzNiwwMDAwMDAwMGM1MjQ3YmM1MTBhZjk5OTJjNDlmZWY1NDNkOWE0Yjdj',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXafD1g5rer7q/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXafD1g5rer7q'},
#    {'collaborative': False,
#     'description': 'Find our playlist with these keywords: all time edm playlist - most famous edm songs - the greatest edm - edm all time - electronic dance music playlist - edm songs of all time - all time edm hits - most viewed edm songs of all time - most popular edm music - best electronic dance music of all time',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2W32HNDe5OgNsPvciLm1Ix'},
#     'href': 'https://api.spotify.com/v1/playlists/2W32HNDe5OgNsPvciLm1Ix',
#     'id': '2W32HNDe5OgNsPvciLm1Ix',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb308bedcde86516706929bbe0',
#       'width': None}],
#     'name': 'Best EDM Songs of All Time - Most Popular EDM Music Playlist',
#     'owner': {'display_name': 'redmusiccompany',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/redmusiccompany'},
#      'href': 'https://api.spotify.com/v1/users/redmusiccompany',
#      'id': 'redmusiccompany',
#      'type': 'user',
#      'uri': 'spotify:user:redmusiccompany'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NzY2NywzNDBkYzU3MzUwYmFjMDMzNjU0NjcwZWZiNDEwOGI3NjhiZDY2NTA4',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2W32HNDe5OgNsPvciLm1Ix/tracks',
#      'total': 130},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2W32HNDe5OgNsPvciLm1Ix'},
#    {'collaborative': False,
#     'description': 'EDM Trance music picked just for you',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EIfUQ3GUkdGYn'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIfUQ3GUkdGYn',
#     'id': '37i9dQZF1EIfUQ3GUkdGYn',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/desc/EDM%20Trance/en/large',
#       'width': None}],
#     'name': 'EDM Trance Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTk3MjAsMDAwMDAwMDBlN2ZiN2EzODdhMzdkZTBjNTI1OGM3ODdlMDljYWU4MQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIfUQ3GUkdGYn/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EIfUQ3GUkdGYn'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/3vdYDhTPS1399eLUzsrPJE'},
#     'href': 'https://api.spotify.com/v1/playlists/3vdYDhTPS1399eLUzsrPJE',
#     'id': '3vdYDhTPS1399eLUzsrPJE',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273472c58102c67fd247d7707b6ab67616d0000b2734cfcceb6f9b1aae8752810e7ab67616d0000b2736f91180b662ca15ad2fb88f0ab67616d0000b273941dd3b3343d9cb9329d37bf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273472c58102c67fd247d7707b6ab67616d0000b2734cfcceb6f9b1aae8752810e7ab67616d0000b2736f91180b662ca15ad2fb88f0ab67616d0000b273941dd3b3343d9cb9329d37bf',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273472c58102c67fd247d7707b6ab67616d0000b2734cfcceb6f9b1aae8752810e7ab67616d0000b2736f91180b662ca15ad2fb88f0ab67616d0000b273941dd3b3343d9cb9329d37bf',
#       'width': 60}],
#     'name': '2013-2015 EDM Hits',
#     'owner': {'display_name': 'Derick',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/derickjoshua'},
#      'href': 'https://api.spotify.com/v1/users/derickjoshua',
#      'id': 'derickjoshua',
#      'type': 'user',
#      'uri': 'spotify:user:derickjoshua'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'OTYsZWJjMDFhOWFiNDA5ZTIyODMzNTBmYzVjMWY4ODgzNzljM2M4NWIwMg==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3vdYDhTPS1399eLUzsrPJE/tracks',
#      'total': 51},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3vdYDhTPS1399eLUzsrPJE'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0GoQedvZwO4jaWgtdZXOEs'},
#     'href': 'https://api.spotify.com/v1/playlists/0GoQedvZwO4jaWgtdZXOEs',
#     'id': '0GoQedvZwO4jaWgtdZXOEs',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbb9c5fff3ac0b4643bed10912',
#       'width': None}],
#     'name': 'EDM/HOUSE BANGERS',
#     'owner': {'display_name': 'gabipontius',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/gabirpontius'},
#      'href': 'https://api.spotify.com/v1/users/gabirpontius',
#      'id': 'gabirpontius',
#      'type': 'user',
#      'uri': 'spotify:user:gabirpontius'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTA0OCxiODkwNDVlMzYzNGZkMGFmZGY2MjFlNzE4ZjkwOTljODI5OWMxNGM3',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0GoQedvZwO4jaWgtdZXOEs/tracks',
#      'total': 614},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0GoQedvZwO4jaWgtdZXOEs'},
#    {'collaborative': False,
#     'description': 'EDM Trap music picked just for you',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EIcYnqRyjGKz9'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIcYnqRyjGKz9',
#     'id': '37i9dQZF1EIcYnqRyjGKz9',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/desc/EDM%20Trap/en/large',
#       'width': None}],
#     'name': 'EDM Trap Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTk3MjAsMDAwMDAwMDA4OGJkZmM1M2ExMThjYTRmM2M4ZmZjY2Q3OTI0MDlmZg==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIcYnqRyjGKz9/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EIcYnqRyjGKz9'},
#    {'collaborative': False,
#     'description': 'The Best EDM Songs of 2023. Featuring artists like: Martin Garrix, Marshmello, R3HAB, David Guetta, Tiësto, Alan Walker, Don Diablo, ILLENIUM, Matisse &amp;amp;amp; Sadko, Brooks, Galantis, MOTI, Kygo and many more... The best dance hits and party music bass future house',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/1IjelnEHVvg008UVRbbSN5'},
#     'href': 'https://api.spotify.com/v1/playlists/1IjelnEHVvg008UVRbbSN5',
#     'id': '1IjelnEHVvg008UVRbbSN5',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbcffe4e60765d9c23cb9c0aa0',
#       'width': None}],
#     'name': 'Best EDM Playlist of 2023',
#     'owner': {'display_name': 'Elias Playlists',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/elias.weber'},
#      'href': 'https://api.spotify.com/v1/users/elias.weber',
#      'id': 'elias.weber',
#      'type': 'user',
#      'uri': 'spotify:user:elias.weber'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'ODIyNyxlMmRkYzgxZmY3MDY2MDQ4ZGM3OWMxYjZkMzZlMTc1ZTkwYzViYzk1',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/1IjelnEHVvg008UVRbbSN5/tracks',
#      'total': 238},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1IjelnEHVvg008UVRbbSN5'},
#    {'collaborative': False,
#     'description': 'DM for submissions @mia.mk',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2u9vDT08uNbGUXv4mv18sk'},
#     'href': 'https://api.spotify.com/v1/playlists/2u9vDT08uNbGUXv4mv18sk',
#     'id': '2u9vDT08uNbGUXv4mv18sk',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb9ea175aa245b7a5d8982bf4f',
#       'width': None}],
#     'name': 'EDM Study/Work (No Lyrics)',
#     'owner': {'display_name': 'Mia Karlsrud',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/miametheny11'},
#      'href': 'https://api.spotify.com/v1/users/miametheny11',
#      'id': 'miametheny11',
#      'type': 'user',
#      'uri': 'spotify:user:miametheny11'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjY5LDMxNzQyMWU2MzU1NjVlMDE3ODY5ZmJkMGFhYWU3MjcwZTdiMTE3YmM=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2u9vDT08uNbGUXv4mv18sk/tracks',
#      'total': 151},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2u9vDT08uNbGUXv4mv18sk'},
#    {'collaborative': False,
#     'description': 'Dance Party EDM music picked just for you',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EIf59I8rQ5zu5'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIf59I8rQ5zu5',
#     'id': '37i9dQZF1EIf59I8rQ5zu5',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/desc/Dance%20Party%20EDM/en/large',
#       'width': None}],
#     'name': 'Dance Party EDM Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTk3MjAsMDAwMDAwMDA2N2VkYzJjOWE0M2M4ZWVhMjY2MGJmM2I1ZGRkZDlhMg==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIf59I8rQ5zu5/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EIf59I8rQ5zu5'},
#    {'collaborative': False,
#     'description': 'Chill electronic music and deep house playlist.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/6BFSF01u3dDgGU7sCMZ28A'},
#     'href': 'https://api.spotify.com/v1/playlists/6BFSF01u3dDgGU7sCMZ28A',
#     'id': '6BFSF01u3dDgGU7sCMZ28A',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb9ebaa515a447de60bfbdfd1f',
#       'width': None}],
#     'name': 'EDM Chill 2024',
#     'owner': {'display_name': 'Phonix Lab',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/t8w9dojs72e99167uwmde65tp'},
#      'href': 'https://api.spotify.com/v1/users/t8w9dojs72e99167uwmde65tp',
#      'id': 't8w9dojs72e99167uwmde65tp',
#      'type': 'user',
#      'uri': 'spotify:user:t8w9dojs72e99167uwmde65tp'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'ODAsYWRkNmQ2ZmZlZjhlNDkxOWQ2MjljZTI0MDUxNTA5NDBmYzc0MDdkZA==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/6BFSF01u3dDgGU7sCMZ28A/tracks',
#      'total': 49},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6BFSF01u3dDgGU7sCMZ28A'},
#    {'collaborative': False,
#     'description': 'EDM WORKOUT &amp; MOTIVATION 💪 The perfect list for workout, gym, cardio &amp; running motivation. Contact <a href="https://instagram.com/tribaltrap">@tribaltrap</a>',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/71z6BdHlnfNj4DKRhuu1Fk'},
#     'href': 'https://api.spotify.com/v1/playlists/71z6BdHlnfNj4DKRhuu1Fk',
#     'id': '71z6BdHlnfNj4DKRhuu1Fk',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb684558b4ace3e395ddb52f15',
#       'width': None}],
#     'name': 'RAGE 💪 EDM WORKOUT MOTIVATION',
#     'owner': {'display_name': 'Tribal Trap',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/tribaltrap'},
#      'href': 'https://api.spotify.com/v1/users/tribaltrap',
#      'id': 'tribaltrap',
#      'type': 'user',
#      'uri': 'spotify:user:tribaltrap'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NjU1OSw2MzhjNTkyZTMxYWE2ZTI4ODU2YmVjZTdlOTk5NTFjZTg0ZWVlZGQ5',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/71z6BdHlnfNj4DKRhuu1Fk/tracks',
#      'total': 109},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:71z6BdHlnfNj4DKRhuu1Fk'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2InZ5xv9hEhOQXN5Cgtcty'},
#     'href': 'https://api.spotify.com/v1/playlists/2InZ5xv9hEhOQXN5Cgtcty',
#     'id': '2InZ5xv9hEhOQXN5Cgtcty',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273167ae216190480d205a638ccab67616d0000b273476bac38962ede4234bd1747ab67616d0000b27369c3e2f8f46672135854f560ab67616d0000b273a44d5b232c7b021a6df3a3e8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273167ae216190480d205a638ccab67616d0000b273476bac38962ede4234bd1747ab67616d0000b27369c3e2f8f46672135854f560ab67616d0000b273a44d5b232c7b021a6df3a3e8',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273167ae216190480d205a638ccab67616d0000b273476bac38962ede4234bd1747ab67616d0000b27369c3e2f8f46672135854f560ab67616d0000b273a44d5b232c7b021a6df3a3e8',
#       'width': 60}],
#     'name': 'EDM',
#     'owner': {'display_name': 'Tim Mac',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/124364488'},
#      'href': 'https://api.spotify.com/v1/users/124364488',
#      'id': '124364488',
#      'type': 'user',
#      'uri': 'spotify:user:124364488'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjgxLDZmM2QwOWE2MzYyZDcxYzQ4ODBkNWI0MTA5NWQ2MTE2MDIzZmNlMzU=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2InZ5xv9hEhOQXN5Cgtcty/tracks',
#      'total': 136},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2InZ5xv9hEhOQXN5Cgtcty'},
#    {'collaborative': False,
#     'description': 'Running EDM music picked just for you',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EIftLWKaBD2r4'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIftLWKaBD2r4',
#     'id': '37i9dQZF1EIftLWKaBD2r4',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/desc/Running%20EDM/en/large',
#       'width': None}],
#     'name': 'Running EDM Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTk3MjAsMDAwMDAwMDBkM2RiZjkxMGQxNTcyN2NiNGE0ZjkyNDZiNjQ1NmMwOQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIftLWKaBD2r4/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EIftLWKaBD2r4'},
#    {'collaborative': False,
#     'description': 'Xmas EDM!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/47h1lEP3L0EJAa28IWUa5W'},
#     'href': 'https://api.spotify.com/v1/playlists/47h1lEP3L0EJAa28IWUa5W',
#     'id': '47h1lEP3L0EJAa28IWUa5W',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb6408b6edd25e4785b485e517',
#       'width': None}],
#     'name': 'EDM Christmas Remixes 2023',
#     'owner': {'display_name': 'Den Haku Records',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/ywuydivm5d8upiut8z0ylm4sh'},
#      'href': 'https://api.spotify.com/v1/users/ywuydivm5d8upiut8z0ylm4sh',
#      'id': 'ywuydivm5d8upiut8z0ylm4sh',
#      'type': 'user',
#      'uri': 'spotify:user:ywuydivm5d8upiut8z0ylm4sh'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjcsMWMzNDNhOWExYjAyMTlkMmQ3ODFhMWZkMzk4NTQ5YTM5MWIwMzU3Mw==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/47h1lEP3L0EJAa28IWUa5W/tracks',
#      'total': 45},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:47h1lEP3L0EJAa28IWUa5W'},
#    {'collaborative': False,
#     'description': 'Dance and Electronic tracks for the season <3',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX2zhLcnFr1qI'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2zhLcnFr1qI',
#     'id': '37i9dQZF1DX2zhLcnFr1qI',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000348def2d6f9c6744f16f0697d',
#       'width': None}],
#     'name': 'Electronic Christmas',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTcwMzIyMTIwMCwwMDAwMDAwMDExNjU0ZDc2YzQwNTEzMGQzOWI4OGQ4MWY3ZjE0NGI0',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2zhLcnFr1qI/tracks',
#      'total': 60},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX2zhLcnFr1qI'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/5DEP6JmI1D9MIkyg3OmThW'},
#     'href': 'https://api.spotify.com/v1/playlists/5DEP6JmI1D9MIkyg3OmThW',
#     'id': '5DEP6JmI1D9MIkyg3OmThW',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-fa.spotifycdn.com/image/ab67706c0000bebbc7694b42b1404631d64eaef0',
#       'width': None}],
#     'name': 'EDM NO PAIN',
#     'owner': {'display_name': 'Introvert Mood',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31f7nsxc3fsd3wo4sd7x3quulwqq'},
#      'href': 'https://api.spotify.com/v1/users/31f7nsxc3fsd3wo4sd7x3quulwqq',
#      'id': '31f7nsxc3fsd3wo4sd7x3quulwqq',
#      'type': 'user',
#      'uri': 'spotify:user:31f7nsxc3fsd3wo4sd7x3quulwqq'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'ODksM2U1NjI2OTU4ODFjYWMwNzI3YWI2ZjI0YTBjZGQwM2QwOTU2YTcwMw==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/5DEP6JmI1D9MIkyg3OmThW/tracks',
#      'total': 28},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:5DEP6JmI1D9MIkyg3OmThW'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/5UeDwkr7YycZRkgqELQIVv'},
#     'href': 'https://api.spotify.com/v1/playlists/5UeDwkr7YycZRkgqELQIVv',
#     'id': '5UeDwkr7YycZRkgqELQIVv',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb494e544ceb743f24fb37d4f9',
#       'width': None}],
#     'name': '',
#     'owner': {'display_name': 'jacob10!',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/jacob10%21'},
#      'href': 'https://api.spotify.com/v1/users/jacob10%21',
#      'id': 'jacob10!',
#      'type': 'user',
#      'uri': 'spotify:user:jacob10%21'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzYwLDkzOTRkNmY3YzQ4ZDliYmQ1MzFmOWZlZTgzNmY4NTk3NDQ5YTk1NTA=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/5UeDwkr7YycZRkgqELQIVv/tracks',
#      'total': 214},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:5UeDwkr7YycZRkgqELQIVv'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37lYjLDfZ5AIArod0cIMtR'},
#     'href': 'https://api.spotify.com/v1/playlists/37lYjLDfZ5AIArod0cIMtR',
#     'id': '37lYjLDfZ5AIArod0cIMtR',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb5bd542dbf826d874b2aac4eb',
#       'width': None}],
#     'name': 'EDM For Us',
#     'owner': {'display_name': 'Astronomical Vibes',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31qf3ifzkrospc6to6r2oxeuh4u4'},
#      'href': 'https://api.spotify.com/v1/users/31qf3ifzkrospc6to6r2oxeuh4u4',
#      'id': '31qf3ifzkrospc6to6r2oxeuh4u4',
#      'type': 'user',
#      'uri': 'spotify:user:31qf3ifzkrospc6to6r2oxeuh4u4'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjY2LDRkNTE5Nzc4ZmJhN2NkOTJiYjgwNTgyNTgxNmQ1NDQ1M2IxYTIzNDI=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37lYjLDfZ5AIArod0cIMtR/tracks',
#      'total': 30},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37lYjLDfZ5AIArod0cIMtR'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/3A7ObC3TLm5J3dhpV8xgoi'},
#     'href': 'https://api.spotify.com/v1/playlists/3A7ObC3TLm5J3dhpV8xgoi',
#     'id': '3A7ObC3TLm5J3dhpV8xgoi',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb14155e861da03fdc9b19d7f6',
#       'width': None}],
#     'name': 'EDM TROUBLE',
#     'owner': {'display_name': 'Tan Lines',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/315fkjjnyhdshev53dhjqizldiui'},
#      'href': 'https://api.spotify.com/v1/users/315fkjjnyhdshev53dhjqizldiui',
#      'id': '315fkjjnyhdshev53dhjqizldiui',
#      'type': 'user',
#      'uri': 'spotify:user:315fkjjnyhdshev53dhjqizldiui'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTE5LDZkYzg2YjQ5MjVkZGU3MGJlNTMzNWNjNWMyN2IwMGZmNTJmNjVkMjg=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3A7ObC3TLm5J3dhpV8xgoi/tracks',
#      'total': 27},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3A7ObC3TLm5J3dhpV8xgoi'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/7BJ2I9QGwi3E3H8aAQhdP9'},
#     'href': 'https://api.spotify.com/v1/playlists/7BJ2I9QGwi3E3H8aAQhdP9',
#     'id': '7BJ2I9QGwi3E3H8aAQhdP9',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b27370c9fb75cb91631e1e436d01ab67616d0000b273a846d54ce684aff97bcaf255ab67616d0000b273ac468b0faebe1f0e1bcc59e9ab67616d0000b273eea709cd232b0ac2e9c7e74d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b27370c9fb75cb91631e1e436d01ab67616d0000b273a846d54ce684aff97bcaf255ab67616d0000b273ac468b0faebe1f0e1bcc59e9ab67616d0000b273eea709cd232b0ac2e9c7e74d',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b27370c9fb75cb91631e1e436d01ab67616d0000b273a846d54ce684aff97bcaf255ab67616d0000b273ac468b0faebe1f0e1bcc59e9ab67616d0000b273eea709cd232b0ac2e9c7e74d',
#       'width': 60}],
#     'name': 'Christmas Dubstep/EDM 🎄',
#     'owner': {'display_name': 'Heidee Purvis',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/129337944'},
#      'href': 'https://api.spotify.com/v1/users/129337944',
#      'id': '129337944',
#      'type': 'user',
#      'uri': 'spotify:user:129337944'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'Mjc0LDc3MmMxOTQxOWUwMzA3ODFkMjRiYzE1ZGZiNWMzODU4NTA0NjkxOWQ=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/7BJ2I9QGwi3E3H8aAQhdP9/tracks',
#      'total': 360},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:7BJ2I9QGwi3E3H8aAQhdP9'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2dYQ2fzRTQEWLW8UhXArdT'},
#     'href': 'https://api.spotify.com/v1/playlists/2dYQ2fzRTQEWLW8UhXArdT',
#     'id': '2dYQ2fzRTQEWLW8UhXArdT',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbc24dbcafc0da6ebfedc4948e',
#       'width': None}],
#     'name': 'EDM BOOST 2023',
#     'owner': {'display_name': 'Moodboost',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31fqennhsorfuhpln32zizkp2qv4'},
#      'href': 'https://api.spotify.com/v1/users/31fqennhsorfuhpln32zizkp2qv4',
#      'id': '31fqennhsorfuhpln32zizkp2qv4',
#      'type': 'user',
#      'uri': 'spotify:user:31fqennhsorfuhpln32zizkp2qv4'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'ODIsYjExNDUzN2YyNWFlNDU5ZjAzNTBjYjFjZGZiNWY3N2RhZjMxZDY0MA==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2dYQ2fzRTQEWLW8UhXArdT/tracks',
#      'total': 28},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2dYQ2fzRTQEWLW8UhXArdT'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/3F5dNlvqHbauwbFIPa2mj4'},
#     'href': 'https://api.spotify.com/v1/playlists/3F5dNlvqHbauwbFIPa2mj4',
#     'id': '3F5dNlvqHbauwbFIPa2mj4',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb43066622258b55a15ef8ed10',
#       'width': None}],
#     'name': 'EDM Recognized',
#     'owner': {'display_name': 'HipHop Masters',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31btczvmgazfgjtvrilqvamqox7e'},
#      'href': 'https://api.spotify.com/v1/users/31btczvmgazfgjtvrilqvamqox7e',
#      'id': '31btczvmgazfgjtvrilqvamqox7e',
#      'type': 'user',
#      'uri': 'spotify:user:31btczvmgazfgjtvrilqvamqox7e'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NDA2LDIyYWZiNTZlNTc4NjI3NGNkMmQ3MTk0OTJlN2NkMDFlNDNkNTJjMGE=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3F5dNlvqHbauwbFIPa2mj4/tracks',
#      'total': 27},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3F5dNlvqHbauwbFIPa2mj4'},
#    {'collaborative': False,
#     'description': 'Curated from a wide variety of electronic dance subgenres and artists. Check out my other playlists! Suggestions: DM on IG',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/7m1C1eHUC2kJQL69dGMjaz'},
#     'href': 'https://api.spotify.com/v1/playlists/7m1C1eHUC2kJQL69dGMjaz',
#     'id': '7m1C1eHUC2kJQL69dGMjaz',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbd3e0d03d784d72369feb4f61',
#       'width': None}],
#     'name': 'Top EDM Hits of All Time',
#     'owner': {'display_name': 'Luke Gullickson',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/22z7gq2sv2eblgvg6znceoj7q'},
#      'href': 'https://api.spotify.com/v1/users/22z7gq2sv2eblgvg6znceoj7q',
#      'id': '22z7gq2sv2eblgvg6znceoj7q',
#      'type': 'user',
#      'uri': 'spotify:user:22z7gq2sv2eblgvg6znceoj7q'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTc0NDQsNjM4MGVkNGIzMDhmNDYwMzhiMTJmMjMzYTBmOTUxM2Y1MTI1YTUyZA==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/7m1C1eHUC2kJQL69dGMjaz/tracks',
#      'total': 1630},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:7m1C1eHUC2kJQL69dGMjaz'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/3YlZ8qiU0hFAe1ktKHKMTD'},
#     'href': 'https://api.spotify.com/v1/playlists/3YlZ8qiU0hFAe1ktKHKMTD',
#     'id': '3YlZ8qiU0hFAe1ktKHKMTD',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb7d2798527416f39e921efd0e',
#       'width': None}],
#     'name': 'EDM BREAK BARRIERS',
#     'owner': {'display_name': 'Study Synergy',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31xfpp5kk243f6kf4sbwa2jcemxq'},
#      'href': 'https://api.spotify.com/v1/users/31xfpp5kk243f6kf4sbwa2jcemxq',
#      'id': '31xfpp5kk243f6kf4sbwa2jcemxq',
#      'type': 'user',
#      'uri': 'spotify:user:31xfpp5kk243f6kf4sbwa2jcemxq'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTEyLDM4OTE5YTc5Mzg5MDA4NGNhYWJlNWE0NDA2MWFkMzczMjA0NDNjNjA=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3YlZ8qiU0hFAe1ktKHKMTD/tracks',
#      'total': 25},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3YlZ8qiU0hFAe1ktKHKMTD'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/41bMTfCBt1a4sD55wVHVsU'},
#     'href': 'https://api.spotify.com/v1/playlists/41bMTfCBt1a4sD55wVHVsU',
#     'id': '41bMTfCBt1a4sD55wVHVsU',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbadfe44c570690090749f7de8',
#       'width': None}],
#     'name': 'EDM Take Over',
#     'owner': {'display_name': 'Good Old Days',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31uzknzvow2k7e2m5kw7m5walxce'},
#      'href': 'https://api.spotify.com/v1/users/31uzknzvow2k7e2m5kw7m5walxce',
#      'id': '31uzknzvow2k7e2m5kw7m5walxce',
#      'type': 'user',
#      'uri': 'spotify:user:31uzknzvow2k7e2m5kw7m5walxce'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzgzLGFmZWY0MWI4ZTg4YTdlZjc5ODVmNjA1NmFlYzMxZDAzMzUxMzcxNWU=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/41bMTfCBt1a4sD55wVHVsU/tracks',
#      'total': 28},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:41bMTfCBt1a4sD55wVHVsU'},
#    {'collaborative': False,
#     'description': 'Christmas Dubstep',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0laTFJlycd44RFpS8aza01'},
#     'href': 'https://api.spotify.com/v1/playlists/0laTFJlycd44RFpS8aza01',
#     'id': '0laTFJlycd44RFpS8aza01',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb888d64c39037378b69951d66',
#       'width': None}],
#     'name': 'Dubstep Christmas 2023 🎁',
#     'owner': {'display_name': 'Kyojuro',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31dttazok2z56ijgolvom2swtefe'},
#      'href': 'https://api.spotify.com/v1/users/31dttazok2z56ijgolvom2swtefe',
#      'id': '31dttazok2z56ijgolvom2swtefe',
#      'type': 'user',
#      'uri': 'spotify:user:31dttazok2z56ijgolvom2swtefe'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTMsZDE2YjQ2NDNlYjRlYzU4M2NhNDJmMjU4MmQwYjE0YWYyN2E2MjlmMQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0laTFJlycd44RFpS8aza01/tracks',
#      'total': 23},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0laTFJlycd44RFpS8aza01'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/4JkfLf2qWV2HuR1eyxabTk'},
#     'href': 'https://api.spotify.com/v1/playlists/4JkfLf2qWV2HuR1eyxabTk',
#     'id': '4JkfLf2qWV2HuR1eyxabTk',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbb572d8b50089ca2ad1819ee3',
#       'width': None}],
#     'name': 'EDM Moon Walking',
#     'owner': {'display_name': 'Art Popular',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31sias4bjbl3uq6d4alarz4b53xu'},
#      'href': 'https://api.spotify.com/v1/users/31sias4bjbl3uq6d4alarz4b53xu',
#      'id': '31sias4bjbl3uq6d4alarz4b53xu',
#      'type': 'user',
#      'uri': 'spotify:user:31sias4bjbl3uq6d4alarz4b53xu'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjYwLDQxYjVmMjRjMWRiOGQ4YzE2MzZlMTNmOGIzMzJiZmU5MTNmYjZkZDk=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/4JkfLf2qWV2HuR1eyxabTk/tracks',
#      'total': 28},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:4JkfLf2qWV2HuR1eyxabTk'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/4AGJIGhJjZ56DJiwooQt1Q'},
#     'href': 'https://api.spotify.com/v1/playlists/4AGJIGhJjZ56DJiwooQt1Q',
#     'id': '4AGJIGhJjZ56DJiwooQt1Q',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb0965d23a38bb4b8c11958333',
#       'width': None}],
#     'name': 'EDM CROWD',
#     'owner': {'display_name': 'Funky Town',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31pkyji2stvl3liwah4wyjbswp3m'},
#      'href': 'https://api.spotify.com/v1/users/31pkyji2stvl3liwah4wyjbswp3m',
#      'id': '31pkyji2stvl3liwah4wyjbswp3m',
#      'type': 'user',
#      'uri': 'spotify:user:31pkyji2stvl3liwah4wyjbswp3m'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NjgsNDYxZTRhNjUxYzRjNzBmNWNmNTI4YmE4ZWJjNDJlM2U2OGIzNDRlYw==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/4AGJIGhJjZ56DJiwooQt1Q/tracks',
#      'total': 21},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:4AGJIGhJjZ56DJiwooQt1Q'},
#    {'collaborative': False,
#     'description': 'EDM Rock music picked just for you',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EIdP8ibLRxqPw'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIdP8ibLRxqPw',
#     'id': '37i9dQZF1EIdP8ibLRxqPw',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/desc/EDM%20Rock/en/large',
#       'width': None}],
#     'name': 'EDM Rock Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTk3MjAsMDAwMDAwMDBiOTk0NDcyMTBlMGIxZDkzN2VkOGY2YmIzMGEwNDQxNg==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIdP8ibLRxqPw/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EIdP8ibLRxqPw'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/3Q10kmHe5TgGSXlzZprJco'},
#     'href': 'https://api.spotify.com/v1/playlists/3Q10kmHe5TgGSXlzZprJco',
#     'id': '3Q10kmHe5TgGSXlzZprJco',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273181994c011fa9fb7f61a047bab67616d0000b2734c9e097cba4de9e85d7ea005ab67616d0000b2735b62a82d9ce418ae5fb11e56ab67616d0000b273838a609b4c719fec2ec6c511',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273181994c011fa9fb7f61a047bab67616d0000b2734c9e097cba4de9e85d7ea005ab67616d0000b2735b62a82d9ce418ae5fb11e56ab67616d0000b273838a609b4c719fec2ec6c511',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273181994c011fa9fb7f61a047bab67616d0000b2734c9e097cba4de9e85d7ea005ab67616d0000b2735b62a82d9ce418ae5fb11e56ab67616d0000b273838a609b4c719fec2ec6c511',
#       'width': 60}],
#     'name': 'NASTY DROPS 🤮🤮🤢🤢',
#     'owner': {'display_name': 'DaBaby',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/1159232682'},
#      'href': 'https://api.spotify.com/v1/users/1159232682',
#      'id': '1159232682',
#      'type': 'user',
#      'uri': 'spotify:user:1159232682'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzgsYWNmYjQxZGIxOTAxYTNiNGEwYjBiODg5ZWMyMTU1ODg5Zjc1MmVjYg==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3Q10kmHe5TgGSXlzZprJco/tracks',
#      'total': 37},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3Q10kmHe5TgGSXlzZprJco'},
#    {'collaborative': False,
#     'description': 'EDM, House, Big Room House, Electro House, Drum N Bass, Brostep, Dubstep, Trance &amp; other sub-genre “Dance” tracks',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/4R0uqIbIrhRfuYpRXeH7Sb'},
#     'href': 'https://api.spotify.com/v1/playlists/4R0uqIbIrhRfuYpRXeH7Sb',
#     'id': '4R0uqIbIrhRfuYpRXeH7Sb',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbf5c4215bcf48c8315669d524',
#       'width': None}],
#     'name': '2010-2015 EDM',
#     'owner': {'display_name': 'Luke Chronis',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31dtpkd7ufgf6q5oydnpnmy4viqe'},
#      'href': 'https://api.spotify.com/v1/users/31dtpkd7ufgf6q5oydnpnmy4viqe',
#      'id': '31dtpkd7ufgf6q5oydnpnmy4viqe',
#      'type': 'user',
#      'uri': 'spotify:user:31dtpkd7ufgf6q5oydnpnmy4viqe'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTI0MixjZmQ3N2IxN2Y2YzZhNTRmMDc4ZDFmMzUwMDVmOWQ0MDVkMDk2MTQ5',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/4R0uqIbIrhRfuYpRXeH7Sb/tracks',
#      'total': 857},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:4R0uqIbIrhRfuYpRXeH7Sb'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/6Ummwp97WvACOWWMLHwH3X'},
#     'href': 'https://api.spotify.com/v1/playlists/6Ummwp97WvACOWWMLHwH3X',
#     'id': '6Ummwp97WvACOWWMLHwH3X',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2735c8cfe4b2c4aa89c9c92108eab67616d0000b27376c5c62197115a22b23ff950ab67616d0000b273dcef905cb144d4867119850bab67616d0000b273f46b9d202509a8f7384b90de',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2735c8cfe4b2c4aa89c9c92108eab67616d0000b27376c5c62197115a22b23ff950ab67616d0000b273dcef905cb144d4867119850bab67616d0000b273f46b9d202509a8f7384b90de',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2735c8cfe4b2c4aa89c9c92108eab67616d0000b27376c5c62197115a22b23ff950ab67616d0000b273dcef905cb144d4867119850bab67616d0000b273f46b9d202509a8f7384b90de',
#       'width': 60}],
#     'name': 'Party EDM Pop 2010-2023',
#     'owner': {'display_name': 'gabrieleramos015',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/12154668245'},
#      'href': 'https://api.spotify.com/v1/users/12154668245',
#      'id': '12154668245',
#      'type': 'user',
#      'uri': 'spotify:user:12154668245'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjgzLGRjOGQ4MzI1ZjdmODg4ZmQ3NDA1YWNjNTE4NWM5NDg0ZWY1MjkwMGM=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/6Ummwp97WvACOWWMLHwH3X/tracks',
#      'total': 177},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6Ummwp97WvACOWWMLHwH3X'},
#    {'collaborative': False,
#     'description': "The world's biggest dance hits. Cover: John Summit, Mathame and Camden Cox",
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4dyzvuaRJ0n'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4dyzvuaRJ0n',
#     'id': '37i9dQZF1DX4dyzvuaRJ0n',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000390a589b7b9d7ea69b4a9ffb0',
#       'width': None}],
#     'name': 'mint',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTcwMjY4OTY4OCwwMDAwMDAwMDBhMTVhNjA4ZjcyMWE3NGI3OWU3ZjQyOGVkOTExMDU3',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4dyzvuaRJ0n/tracks',
#      'total': 75},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX4dyzvuaRJ0n'},
#    {'collaborative': False,
#     'description': 'Chill EDM music picked just for you',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EIe8uJuAVjMJL'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIe8uJuAVjMJL',
#     'id': '37i9dQZF1EIe8uJuAVjMJL',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/desc/Chill%20EDM/en/large',
#       'width': None}],
#     'name': 'Chill EDM Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTk3MjAsMDAwMDAwMDA4YTFkNDUzMmMyYzQ0Njk5ODI3NWZmMjMxOTVmMzUxOA==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIe8uJuAVjMJL/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EIe8uJuAVjMJL'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2EdKXUdvgYi6xpWFRqpyYu'},
#     'href': 'https://api.spotify.com/v1/playlists/2EdKXUdvgYi6xpWFRqpyYu',
#     'id': '2EdKXUdvgYi6xpWFRqpyYu',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb9d590df7c0afb6e675cb6cc8',
#       'width': None}],
#     'name': 'CHRISTMAS RAVE',
#     'owner': {'display_name': 'brendenrosario',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/brendenrosario'},
#      'href': 'https://api.spotify.com/v1/users/brendenrosario',
#      'id': 'brendenrosario',
#      'type': 'user',
#      'uri': 'spotify:user:brendenrosario'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NzIsNjgwYjA0ZWM5ZDc5NzBjMGVkOTg0MDMwMjg0ZmQ4YjBjZTk2NTZjNw==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2EdKXUdvgYi6xpWFRqpyYu/tracks',
#      'total': 42},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2EdKXUdvgYi6xpWFRqpyYu'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=edm&type=playlist&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %%
test = pd.DataFrame(results, columns = ['track_id', 'track_name', 'track_artist', 'track_popularity', 'track_album_id', 'track_album_name', 'track_album_release_date', 'playlist_name', 'playlist_id', 'playlist_genre'])

# %%
test
# Out:
#                      track_id                    track_name  \
# 0      5Y2n6pW4Vqr4Mzkd9V4Uk8                  Ray Of Solar
# 1      4b93D55xv3YCH5mT4p6HPn                   Ocean Drive
# 2      0vZCG0H9KhtU7K8MEUVAoV                       Tsunami
# 3      6ho0GyrWZN3mhi9zVRW7xi                     Losing It
# 4      23RoR84KodL5HWvUTneQ1w  (It Goes Like) Nanana - Edit
# ...                       ...                           ...
# 21378  7MfNoHB8JRNbSQ8P3eAfMQ               T-Shirt Weather
# 21379  7EAMXbLcL0qXmciM5SwMh2                Heart To Heart
# 21380  2MYidPOz5NHAtKUySTzbwx                          Paul
# 21381  0hDQV9X1Da5JrwhK8gu86p                          Maps
# 21382  1cwqP7Tyxu5z8XDYoPkNte                    Chandelier
#
#                 track_artist  track_popularity          track_album_id  \
# 0      [Swedish House Mafia]                72  3qoGM4yHcw91XeCA6bC7Pb
# 1              [Duke Dumont]                71  6AlOjPdNpM41lMVSjjsrUM
# 2          [DVBBS, Borgeous]                65  7p38vlEZaMNySKQVSSWUm8
# 3                   [FISHER]                72  143cxYCazoiNfviHRmxkdv
# 4                [Peggy Gou]                86  2LVDNOUUy2g8517ZEtQIcK
# ...                      ...               ...                     ...
# 21378          [Circa Waves]                61  4a5Kj8QND91bSnXTsLUetM
# 21379          [Mac DeMarco]                83  67PsnkYVPNpEsZffyTWGgW
# 21380            [Big Thief]                61  2QVrJXsVZIgwNwOhtu31wd
# 21381      [Yeah Yeah Yeahs]                68  44ePwTuWK88vnalqutqJEG
# 21382          [Will Paquin]                72  1VC4P7rm1o3aYlYVYFkpGF
#
#                         track_album_name track_album_release_date  \
# 0                           Ray Of Solar               2023-08-04
# 1                                Duality               2020-04-17
# 2                                Tsunami               2013-09-02
# 3                              Losing It               2018-07-13
# 4           (It Goes Like) Nanana [Edit]               2023-06-15
# ...                                  ...                      ...
# 21378             Young Chasers (Deluxe)               2015-03-30
# 21379              Here Comes The Cowboy               2019-05-10
# 21380                        Masterpiece               2016-05-27
# 21381  Fever To Tell (Deluxe Remastered)               2003-04-29
# 21382                         Chandelier               2020-09-25
#
#          playlist_name             playlist_id playlist_genre
# 0        EDM House Mix  37i9dQZF1EIdDyy28MYSyS            edm
# 1        EDM House Mix  37i9dQZF1EIdDyy28MYSyS            edm
# 2        EDM House Mix  37i9dQZF1EIdDyy28MYSyS            edm
# 3        EDM House Mix  37i9dQZF1EIdDyy28MYSyS            edm
# 4        EDM House Mix  37i9dQZF1EIdDyy28MYSyS            edm
# ...                ...                     ...            ...
# 21378  Indie Rock Hits  37i9dQZF1DXb9izPIc0SCS           rock
# 21379  Indie Rock Hits  37i9dQZF1DXb9izPIc0SCS           rock
# 21380  Indie Rock Hits  37i9dQZF1DXb9izPIc0SCS           rock
# 21381  Indie Rock Hits  37i9dQZF1DXb9izPIc0SCS           rock
# 21382  Indie Rock Hits  37i9dQZF1DXb9izPIc0SCS           rock
#
# [21383 rows x 10 columns]

# %%
spotify = pd.read_csv(f'{path}spotify.csv')
spotify.head(3)
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
#
#    track_artist  track_popularity          track_album_id  \
# 0    Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1      Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2  Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
#
# [3 rows x 23 columns]

# %%
spotify.groupby('playlist_genre')['playlist_name'].nunique()
# Out:
# playlist_genre
# edm      78
# latin    78
# pop      73
# r&b      76
# rap      77
# rock     72
# Name: playlist_name, dtype: int64

# %% [markdown]
# ## About Dataset
# Almost 30,000 Songs from the Spotify API. See the readme file for a formatted data dictionary table.
#
# ### Data Dictionary:
#
# variable class description
#
# track_id character Song unique ID
#
# track_name character Song Name
#
# track_artist character Song Artist
#
# track_popularity double Song Popularity (0-100) where higher is better
#
# track_album_id character Album unique ID
#
# track_album_name character Song album name
#
# track_album_release_date character Date when album released
#
# playlist_name character Name of playlist
#
# playlist_id character Playlist ID
#
# playlist_genre character Playlist genre
#
# playlist_subgenre character Playlist subgenre
#
# danceability double Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# energy double Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# key double The estimated overall key of the track. Integers map to pitches using standard Pitch Class notation . E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
#
# loudness double The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.
#
# mode double Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
#
# speechiness double Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# acousticness double A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# instrumentalness double Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# liveness double Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# valence double A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# tempo double The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# duration_ms double Duration of song in milliseconds

# %%
spotify['playlist_genre'].value_counts(normalize = True).sort_values(ascending = False)
# Out:
# edm      0.184053
# rap      0.175007
# pop      0.167728
# r&b      0.165413
# latin    0.157007
# rock     0.150793
# Name: playlist_genre, dtype: float64

# %%
spotify['playlist_genre'].value_counts().sort_values(ascending = False)
# Out:
# edm      6043
# rap      5746
# pop      5507
# r&b      5431
# latin    5155
# rock     4951
# Name: playlist_genre, dtype: int64

# %% [markdown]
# # Pistachio types detection

# %%
pistachio = pd.read_csv(f'{path}pistachio.csv')
pistachio.head(3)
# Out:
#     AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  73107   1161.807    442.4074    217.7261        0.8705  305.0946    0.9424
# 1  89272   1173.181    460.2551    251.9546        0.8369  337.1419    0.9641
# 2  60955    999.789    386.9247    209.1255        0.8414  278.5863    0.9465
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  SHAPEFACTOR_1  \
# 0        77579  0.7710        2.0319     0.6806       0.6896         0.0061
# 1        92598  0.7584        1.8267     0.8151       0.7325         0.0052
# 2        64400  0.7263        1.8502     0.7663       0.7200         0.0063
#
#    SHAPEFACTOR_2  SHAPEFACTOR_3  SHAPEFACTOR_4              Class
# 0         0.0030         0.4756         0.9664  Kirmizi_Pistachio
# 1         0.0028         0.5366         0.9802     Siit_Pistachio
# 2         0.0034         0.5184         0.9591  Kirmizi_Pistachio

# %%
pistachio['Class'].unique()
# Out:
# array(['Kirmizi_Pistachio', 'Siit_Pistachio'], dtype=object)

# %%
pistachio.shape
# Out:
# (1718, 17)

# %% [markdown]
# # Avocado Price / Classification

# %% [markdown]
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV. Here's how the Hass Avocado Board describes the data on their website:
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados. Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags. The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# #### Some relevant columns in the dataset:
#
# Date - The date of the observation
#
# AveragePrice - the average price of a single avocado
#
# type - conventional or organic
#
# year - the year
#
# Region - the city or region of the observation
#
# Total Volume - Total number of avocados sold
#
# 4046 - Total number of avocados with PLU 4046 sold
#
# 4225 - Total number of avocados with PLU 4225 sold
#
# 4770 - Total number of avocados with PLU 4770 sold

# %%
avocado = pd.read_csv(f'{path}avocado.csv')
avocado.head(5)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
avocado['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
avocado.shape
# Out:
# (18249, 14)

# %%
avocado['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
avocado.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# # Glassdoor Job Reviews NLP
#
# #### About Dataset
#
# This large dataset contains job descriptions and rankings among various criteria such as work-life balance, income, culture, etc. The data covers the various industry in the UK. Great dataset for multidimensional sentiment analysis.
#
# #### Glassdoor Reviews
#
# Glassdoor produces reports based upon the data collected from its users, on topics including work–life balance, CEO pay-ratios, lists of the best office places and cultures, and the accuracy of corporate job searching maxims. Data from Glassdoor has also been used by outside sources to produce estimates on the effects of salary trends and changes on corporate revenues. Glassdoor also puts the conclusions of its research of other companies towards its own company policies. In 2015, Tom Lakin produced the first study of Glassdoor in the United Kingdom, concluding that Glassdoor is regarded by users as a more trustworthy source of information than career guides or official company documents.
#
# #### Features
#
# The columns correspond to the date of the review, the job name, the job location, the status of the reviewers, and the reviews. Reviews are divided in s sub-categories Career Opportunities, Comp & Benefits, Culture & Values, Senior Management, and Work/Life Balance. In addition, employees can add recommendations on the firm, the CEO, and the outlook.
#
# #### Other information
#
# Ranking for the recommendation of the firm, CEO approval, and outlook are allocated categories v, r, x, and o, with the following meanings:
# v - Positive, r - Mild, x - Negative, o - No opinion
#
# #### Some examples of the textual data entries
#
# ##### MCDONALD-S
# I don't like working here,don't work here
#
# Headline: I don't like working here,don't work here
#
# Pros: Some people are nice,some free food,some of the managers are nice about 95% of the time
#
# Cons: 95% of people are mean to employees/customers,its not a clean place,people barely clean their hands of what i see,managers are mean,i got a stress rash because of this i can't get rid of it,they don't give me a little raise even though i do alot of crap there for them
#
# Rating: 1.0

# %%
gd = pd.read_csv(f'{path}glassdoor_reviews.csv')
gd.head(5)
# Out:
#                     firm date_review              job_title  \
# 0  AFH-Wealth-Management  2015-04-05
# 1  AFH-Wealth-Management  2015-12-11   Office Administrator
# 2  AFH-Wealth-Management  2016-01-28   Office Administrator
# 3  AFH-Wealth-Management  2016-04-16
# 4  AFH-Wealth-Management  2016-04-23   Office Administrator
#
#                               current                      location  \
# 0                    Current Employee                           NaN
# 1  Current Employee, more than 1 year  Bromsgrove, England, England
# 2  Current Employee, less than 1 year  Bromsgrove, England, England
# 3                    Current Employee                           NaN
# 4  Current Employee, more than 1 year  Bromsgrove, England, England
#
#    overall_rating  work_life_balance  culture_values  diversity_inclusion  \
# 0               2                4.0             3.0                  NaN
# 1               2                3.0             1.0                  NaN
# 2               1                1.0             1.0                  NaN
# 3               5                2.0             3.0                  NaN
# 4               1                2.0             1.0                  NaN
#
#    career_opp  comp_benefits  senior_mgmt recommend ceo_approv outlook  \
# 0         2.0            3.0          3.0         x          o       r
# 1         2.0            1.0          4.0         x          o       r
# 2         1.0            1.0          1.0         x          o       x
# 3         2.0            2.0          3.0         x          o       r
# 4         2.0            1.0          1.0         x          o       x
#
#                                   headline  \
# 0  Young colleagues, poor micro management
# 1             Excellent staff, poor salary
# 2          Low salary, bad micromanagement
# 3            Over promised under delivered
# 4                   client reporting admin
#
#                                                 pros  \
# 0  Very friendly and welcoming to new staff. Easy...
# 1      Friendly, helpful and hard-working colleagues
# 2  Easy to get the job even without experience in...
# 3                            Nice staff to work with
# 4              Easy to get the job, Nice colleagues.
#
#                                                 cons
# 0    Poor salaries, poor training and communication.
# 1  Poor salary which doesn't improve much with pr...
# 2  Very low salary, poor working conditions, very...
# 3           No career progression and salary is poor
# 4  Abysmal pay, around minimum wage. No actual tr...

# %%
gd['firm'].value_counts(ascending = False).head(10)
# Out:
# IBM           60436
# McDonald-s    49450
# Deloitte      46995
# EY            34050
# PwC           33227
# Oracle        31941
# Microsoft     26675
# J-P-Morgan    25814
# KPMG          24815
# Apple         20797
# Name: firm, dtype: int64

# %%
gd['firm'].value_counts(ascending = False).head(10).sum()
# Out:
# 354200

# %%
gd.shape
# Out:
# (838566, 18)

# %%
gd.columns
# Out:
# Index(['firm', 'date_review', 'job_title', 'current', 'location',
#        'overall_rating', 'work_life_balance', 'culture_values',
#        'diversity_inclusion', 'career_opp', 'comp_benefits', 'senior_mgmt',
#        'recommend', 'ceo_approv', 'outlook', 'headline', 'pros', 'cons'],
#       dtype='object')

# %%
gd['ceo_approv'].value_counts()
# Out:
# o    311433
# v    286695
# r    176930
# x     63508
# Name: ceo_approv, dtype: int64

# %%
[x for x in dir(pd.DataFrame) if 'na' in x]
# Out:
# ['__finalize__',
#  '_as_manager',
#  '_get_axis_name',
#  '_get_block_manager_axis',
#  '_info_axis_name',
#  '_internal_names',
#  '_internal_names_set',
#  '_rename',
#  '_set_axis_name',
#  '_stat_axis_name',
#  'dropna',
#  'fillna',
#  'isna',
#  'notna',
#  'rename',
#  'rename_axis']

# %%
gd.select_dtypes('number').columns
# Out:
# Index(['overall_rating', 'work_life_balance', 'culture_values',
#        'diversity_inclusion', 'career_opp', 'comp_benefits', 'senior_mgmt'],
#       dtype='object')

# %%
gd['rating'] = gd[['work_life_balance', 'culture_values', 'career_opp', 'comp_benefits', 'senior_mgmt']].mean(axis = 1)

# %%
gd[['overall_rating', 'rating']]
# Out:
#         overall_rating  rating
# 0                    2     3.0
# 1                    2     2.2
# 2                    1     1.0
# 3                    5     2.4
# 4                    1     1.4
# ...                ...     ...
# 838561               5     4.2
# 838562               3     NaN
# 838563               4     4.2
# 838564               5     NaN
# 838565               5     4.6
#
# [838566 rows x 2 columns]

# %%
gd[['work_life_balance', 'culture_values', 'career_opp', 'comp_benefits', 'senior_mgmt']].isna().sum().sort_values()
# Out:
# career_opp           147501
# work_life_balance    149894
# comp_benefits        150082
# senior_mgmt          155876
# culture_values       191373
# dtype: int64

# %%
df1 = gd.drop('diversity_inclusion', axis = 1).copy()

# %%
df1 = df1.dropna(subset = ['work_life_balance', 'culture_values', 'career_opp', 'comp_benefits', 'senior_mgmt'])

# %%
df1.shape, gd.shape
# Out:
# ((637409, 18), (838566, 19))

# %%
df2[['work_life_balance', 'culture_values', 'career_opp', 'comp_benefits', 'senior_mgmt']].isna().sum().sort_values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df2[['work_life_balance', 'culture_values', 'career_opp', 'comp_benefits', 'senior_mgmt']].isna().sum().sort_values()
#
# NameError: name 'df2' is not defined

# %%
df1.head(1)
